# %%
import os.path as osp
import random
import time
import datetime
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data as data

# %%
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

import warnings
warnings.filterwarnings('ignore')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用GPU：", device)
# Out:
# 使用GPU： cuda:0

# %%
from utils.ssd_model import make_datapath_list, VOCDataset, DataTransform, Anno_xml2list, od_collate_fn


# ファイルパスのリストを取得
rootpath = "../0_datasets/2_VOC2012/VOCdevkit/VOC2012/"
train_img_list, train_anno_list, val_img_list, val_anno_list = make_datapath_list(
    rootpath)

# Datasetを作成
voc_classes = ['aeroplane', 'bicycle', 'bird', 'boat',
               'bottle', 'bus', 'car', 'cat', 'chair',
               'cow', 'diningtable', 'dog', 'horse',
               'motorbike', 'person', 'pottedplant',
               'sheep', 'sofa', 'train', 'tvmonitor']
color_mean = (104, 117, 123)  # (BGR)の色の平均値
input_size = 300  # 画像のinputサイズを300×300にする

train_dataset = VOCDataset(train_img_list, train_anno_list, phase="train", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))

val_dataset = VOCDataset(val_img_list, val_anno_list, phase="val", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))


# DataLoaderを作成する
batch_size = 32

train_dataloader = data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, collate_fn=od_collate_fn)

val_dataloader = data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False, collate_fn=od_collate_fn)

# 辞書オブジェクトにまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# %%
from utils.ssd_model import SSD

# SSD300の設定
ssd_cfg = {
    'num_classes': 21,  # 背景クラスを含めた合計クラス数
    'input_size': 300,  # 画像の入力サイズ
    'bbox_aspect_num': [4, 6, 6, 6, 4, 4],  # 出力するDBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# SSDネットワークモデル
net = SSD(phase="train", cfg=ssd_cfg)

# SSDの初期の重みを設定
# ssdのvgg部分に重みをロードする
vgg_weights = torch.load('./weights/vgg16_reducedfc.pth')
net.vgg.load_state_dict(vgg_weights)

# ssdのその他のネットワークの重みはHeの初期値で初期化


def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:  # バイアス項がある場合
            nn.init.constant_(m.bias, 0.0)


# Heの初期値を適用
net.extras.apply(weights_init)
net.loc.apply(weights_init)
net.conf.apply(weights_init)

# GPUが使えるかを確認
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)

print('ネットワーク設定完了：学習済みの重みをロードしました')
# Out:
# 使用デバイス： cuda:0
# ネットワーク設定完了：学習済みの重みをロードしました

# %%
from utils.ssd_model import MultiBoxLoss

# 損失関数の設定
criterion = MultiBoxLoss(jaccard_thresh=0.5, neg_pos=3, device=device)

# 最適化手法の設定
optimizer = optim.SGD(net.parameters(), lr=1e-3,
                      momentum=0.9, weight_decay=5e-4)

# %%
def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):
    
    time_name = datetime.datetime.now().strftime(f'%Y-%m-%d-%H-%M')

    # GPU是否可用
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用cuda：", device)

    # 网络放入GPU中
    net.to(device)

    # 网络稳定后，开启告诉运算
    torch.backends.cudnn.benchmark = True

    # 迭代计数器
    iteration = 1
    epoch_train_loss = 0.0  # epochの損失和
    epoch_val_loss = 0.0  # epochの損失和
    logs = []

    # epochのループ
    for epoch in range(num_epochs+1):

        # 開始時刻 保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # 以epoch为单位进行训练和验证
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
                print('（train）')
            else:
                if((epoch+1) % 10 == 0):
                    net.eval()  # 每10轮进行一次验证
                    print('-------------')
                    print('（val）')
                else:
                    # 検証は10回に1回だけ行う
                    continue

            # 加载数据
            for images, targets in dataloaders_dict[phase]:

                # GPU 
                images = images.to(device)
                targets = [ann.to(device)
                           for ann in targets]  # リストの各要素のテンソルをGPUへ

                # optimizer初始化
                optimizer.zero_grad()

                # 正向传播计算
                with torch.set_grad_enabled(phase == 'train'):
                    # 正向forward计算
                    outputs = net(images)

                    # 计算损失值
                    loss_l, loss_c = criterion(outputs, targets)
                    loss = loss_l + loss_c

                    # 训练时候，开启反向传播
                    if phase == 'train':
                        loss.backward()  # 计算梯度

                        # 如果梯度太大，计算会变得不稳定，因此，使用clip将梯度固定在2.0以内
                        nn.utils.clip_grad_value_(
                            net.parameters(), clip_value=2.0)

                        optimizer.step()  # 更新优化器参数

                        if (iteration % 10 == 0):  # 每10次迭代，显示一次loss
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            print('迭代 {} || Loss: {:.4f} || 10iter: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        epoch_train_loss += loss.item()
                        iteration += 1

                    # 验证时
                    else:
                        epoch_val_loss += loss.item()

        # 以epoch的phase为单位的loss和准确率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_TRAIN_Loss:{:.4f} ||Epoch_VAL_Loss:{:.4f}'.format(
            epoch+1, epoch_train_loss, epoch_val_loss)) # # 每10轮进行一次验证
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        # 日志保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss, 'val_loss': epoch_val_loss}
        logs.append(log_epoch)
        df = pd.DataFrame(logs)
        df.to_csv("log_output.csv")

        epoch_train_loss = 0.0  # 重置每个epoch的损失值
        epoch_val_loss = 0.0  # 重置每个epoch的损失值

        save_path_dir = './weights/{}/'.format(time_name)
        if not os.path.exists(save_path_dir):
            os.mkdir(save_path_dir)
        # 保存网络
        if ((epoch+1) % 10 == 0):
            torch.save(net.state_dict(), save_path_dir+'ssd300_' +
                       str(epoch+1) + '.pth')

# %%
num_epochs= 200
train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
# Out:
# 使用cuda： cuda:0
# -------------
# Epoch 1/50
# -------------
# （train）
# 迭代 10 || Loss: 16.5951 || 10iter: 18.8621 sec.
# 迭代 20 || Loss: 12.9367 || 10iter: 10.5288 sec.
# 迭代 30 || Loss: 10.0232 || 10iter: 10.4310 sec.
# 迭代 40 || Loss: 8.8253 || 10iter: 10.5955 sec.
# 迭代 50 || Loss: 8.1213 || 10iter: 10.4149 sec.
# 迭代 60 || Loss: 8.0902 || 10iter: 11.2239 sec.
# 迭代 70 || Loss: 8.1816 || 10iter: 10.8522 sec.
# 迭代 80 || Loss: 7.5824 || 10iter: 10.6353 sec.
# 迭代 90 || Loss: 7.9694 || 10iter: 10.7503 sec.
# 迭代 100 || Loss: 7.6256 || 10iter: 10.4296 sec.
# 迭代 110 || Loss: 7.3194 || 10iter: 10.6699 sec.
# 迭代 120 || Loss: 7.0807 || 10iter: 10.3945 sec.
# 迭代 130 || Loss: 7.5506 || 10iter: 10.4725 sec.
# 迭代 140 || Loss: 7.5016 || 10iter: 10.7087 sec.
# 迭代 150 || Loss: 7.0530 || 10iter: 10.5181 sec.
# 迭代 160 || Loss: 7.5662 || 10iter: 10.7053 sec.
# 迭代 170 || Loss: 7.2159 || 10iter: 10.7073 sec.
# -------------
# epoch 1 || Epoch_TRAIN_Loss:1620.4075 ||Epoch_VAL_Loss:0.0000
# timer:  207.5266 sec.
# -------------
# Epoch 2/50
# -------------
# （train）
# 迭代 180 || Loss: 7.5979 || 10iter: 0.7941 sec.
# 迭代 190 || Loss: 7.2567 || 10iter: 10.4024 sec.
# 迭代 200 || Loss: 7.1423 || 10iter: 10.5376 sec.
# 迭代 210 || Loss: 6.5939 || 10iter: 10.6640 sec.
# 迭代 220 || Loss: 6.9241 || 10iter: 10.7113 sec.
# 迭代 230 || Loss: 6.9700 || 10iter: 10.4347 sec.
# 迭代 240 || Loss: 6.7797 || 10iter: 10.6512 sec.
# 迭代 250 || Loss: 6.8298 || 10iter: 10.5420 sec.
# 迭代 260 || Loss: 6.8721 || 10iter: 10.7120 sec.
# 迭代 270 || Loss: 7.1052 || 10iter: 10.7059 sec.
# 迭代 280 || Loss: 6.6046 || 10iter: 10.6190 sec.
# 迭代 290 || Loss: 6.4960 || 10iter: 10.7441 sec.
# 迭代 300 || Loss: 6.2143 || 10iter: 11.1715 sec.
# 迭代 310 || Loss: 6.9018 || 10iter: 10.6039 sec.
# 迭代 320 || Loss: 6.6690 || 10iter: 10.4842 sec.
# 迭代 330 || Loss: 6.9900 || 10iter: 10.6116 sec.
# 迭代 340 || Loss: 6.3160 || 10iter: 10.5220 sec.
# 迭代 350 || Loss: 6.9079 || 10iter: 10.8352 sec.
# -------------
# epoch 2 || Epoch_TRAIN_Loss:1246.4851 ||Epoch_VAL_Loss:0.0000
# timer:  196.4667 sec.
# -------------
# Epoch 3/50
# -------------
# （train）
# 迭代 360 || Loss: 6.7055 || 10iter: 1.7869 sec.
# 迭代 370 || Loss: 6.6003 || 10iter: 10.6509 sec.
# 迭代 380 || Loss: 6.5483 || 10iter: 10.6697 sec.
# 迭代 390 || Loss: 6.6370 || 10iter: 10.6488 sec.
# 迭代 400 || Loss: 7.5788 || 10iter: 10.7666 sec.
# 迭代 410 || Loss: 6.5068 || 10iter: 10.6071 sec.
# 迭代 420 || Loss: 6.6584 || 10iter: 10.6419 sec.
# 迭代 430 || Loss: 6.4280 || 10iter: 10.5657 sec.
# 迭代 440 || Loss: 6.6854 || 10iter: 10.9030 sec.
# 迭代 450 || Loss: 6.5318 || 10iter: 10.9013 sec.
# 迭代 460 || Loss: 6.2835 || 10iter: 10.7105 sec.
# 迭代 470 || Loss: 6.6283 || 10iter: 11.0121 sec.
# 迭代 480 || Loss: 6.4347 || 10iter: 10.5852 sec.
# 迭代 490 || Loss: 6.6804 || 10iter: 10.8481 sec.
# 迭代 500 || Loss: 6.2623 || 10iter: 10.6429 sec.
# 迭代 510 || Loss: 6.1426 || 10iter: 10.6822 sec.
# 迭代 520 || Loss: 6.4387 || 10iter: 10.6056 sec.
# 迭代 530 || Loss: 6.1918 || 10iter: 11.0539 sec.
# -------------
# epoch 3 || Epoch_TRAIN_Loss:1170.0513 ||Epoch_VAL_Loss:0.0000
# timer:  197.9214 sec.
# -------------
# Epoch 4/50
# -------------
# （train）
# 迭代 540 || Loss: 6.1086 || 10iter: 2.9509 sec.
# 迭代 550 || Loss: 6.5867 || 10iter: 11.0799 sec.
# 迭代 560 || Loss: 6.7335 || 10iter: 13.0206 sec.
# 迭代 570 || Loss: 6.0905 || 10iter: 13.4472 sec.
# 迭代 580 || Loss: 6.4944 || 10iter: 13.1834 sec.
# 迭代 590 || Loss: 6.2022 || 10iter: 13.0225 sec.
# 迭代 600 || Loss: 6.6869 || 10iter: 13.2956 sec.
# 迭代 610 || Loss: 6.7224 || 10iter: 13.0185 sec.
# 迭代 620 || Loss: 5.8287 || 10iter: 13.1050 sec.
# 迭代 630 || Loss: 6.3437 || 10iter: 13.1028 sec.
# 迭代 640 || Loss: 6.1298 || 10iter: 13.1524 sec.
# 迭代 650 || Loss: 5.9601 || 10iter: 13.1695 sec.
# 迭代 660 || Loss: 6.1743 || 10iter: 12.8240 sec.
# 迭代 670 || Loss: 6.3983 || 10iter: 13.2920 sec.
# 迭代 680 || Loss: 6.2979 || 10iter: 13.1149 sec.
# 迭代 690 || Loss: 6.0394 || 10iter: 12.8839 sec.
# 迭代 700 || Loss: 6.2938 || 10iter: 13.4197 sec.
# 迭代 710 || Loss: 6.7654 || 10iter: 13.1510 sec.
# -------------
# epoch 4 || Epoch_TRAIN_Loss:1114.5261 ||Epoch_VAL_Loss:0.0000
# timer:  238.2318 sec.
# -------------
# Epoch 5/50
# -------------
# （train）
# 迭代 720 || Loss: 5.9984 || 10iter: 3.9918 sec.
# 迭代 730 || Loss: 5.8168 || 10iter: 10.7751 sec.
# 迭代 740 || Loss: 6.5930 || 10iter: 10.8443 sec.
# 迭代 750 || Loss: 5.6247 || 10iter: 11.0141 sec.
# 迭代 760 || Loss: 6.0007 || 10iter: 10.6740 sec.
# 迭代 770 || Loss: 5.7844 || 10iter: 10.6731 sec.
# 迭代 780 || Loss: 5.6627 || 10iter: 10.5828 sec.
# 迭代 790 || Loss: 6.2606 || 10iter: 10.8452 sec.
# 迭代 800 || Loss: 6.1031 || 10iter: 10.5510 sec.
# 迭代 810 || Loss: 6.4017 || 10iter: 11.0406 sec.
# 迭代 820 || Loss: 6.2779 || 10iter: 10.7952 sec.
# 迭代 830 || Loss: 5.8260 || 10iter: 10.7569 sec.
# 迭代 840 || Loss: 5.8314 || 10iter: 10.8109 sec.
# 迭代 850 || Loss: 5.9723 || 10iter: 10.8417 sec.
# 迭代 860 || Loss: 5.7799 || 10iter: 11.1091 sec.
# 迭代 870 || Loss: 6.1172 || 10iter: 10.9410 sec.
# 迭代 880 || Loss: 5.9899 || 10iter: 10.9963 sec.
# 迭代 890 || Loss: 6.1983 || 10iter: 10.8457 sec.
# -------------
# epoch 5 || Epoch_TRAIN_Loss:1071.8217 ||Epoch_VAL_Loss:0.0000
# timer:  199.7990 sec.
# -------------
# Epoch 6/50
# -------------
# （train）
# 迭代 900 || Loss: 5.9996 || 10iter: 5.1493 sec.
# 迭代 910 || Loss: 5.7946 || 10iter: 10.6603 sec.
# 迭代 920 || Loss: 5.5147 || 10iter: 10.4787 sec.
# 迭代 930 || Loss: 5.8641 || 10iter: 10.7007 sec.
# 迭代 940 || Loss: 5.4719 || 10iter: 10.6037 sec.
# 迭代 950 || Loss: 6.0173 || 10iter: 10.5982 sec.
# 迭代 960 || Loss: 6.1500 || 10iter: 10.5752 sec.
# 迭代 970 || Loss: 6.1359 || 10iter: 10.5178 sec.
# 迭代 980 || Loss: 5.8531 || 10iter: 10.4054 sec.
# 迭代 990 || Loss: 5.2099 || 10iter: 10.3171 sec.
# 迭代 1000 || Loss: 5.9240 || 10iter: 10.7568 sec.
# 迭代 1010 || Loss: 5.7063 || 10iter: 10.6382 sec.
# 迭代 1020 || Loss: 5.6767 || 10iter: 10.5618 sec.
# 迭代 1030 || Loss: 5.8991 || 10iter: 10.7138 sec.
# 迭代 1040 || Loss: 5.4978 || 10iter: 10.7180 sec.
# 迭代 1050 || Loss: 5.5222 || 10iter: 10.5344 sec.
# 迭代 1060 || Loss: 5.5974 || 10iter: 10.6398 sec.
# 迭代 1070 || Loss: 5.7541 || 10iter: 10.5755 sec.
# -------------
# epoch 6 || Epoch_TRAIN_Loss:1031.9176 ||Epoch_VAL_Loss:0.0000
# timer:  195.5825 sec.
# -------------
# Epoch 7/50
# -------------
# （train）
# 迭代 1080 || Loss: 5.6014 || 10iter: 6.3912 sec.
# 迭代 1090 || Loss: 5.3664 || 10iter: 10.6090 sec.
# 迭代 1100 || Loss: 5.8203 || 10iter: 10.4404 sec.
# 迭代 1110 || Loss: 5.0683 || 10iter: 10.5537 sec.
# 迭代 1120 || Loss: 5.2740 || 10iter: 10.6317 sec.
# 迭代 1130 || Loss: 5.3672 || 10iter: 10.9757 sec.
# 迭代 1140 || Loss: 5.4978 || 10iter: 10.6884 sec.
# 迭代 1150 || Loss: 5.5940 || 10iter: 10.6261 sec.
# 迭代 1160 || Loss: 5.4450 || 10iter: 10.8781 sec.
# 迭代 1170 || Loss: 4.7775 || 10iter: 10.8439 sec.
# 迭代 1180 || Loss: 6.0073 || 10iter: 10.6850 sec.
# 迭代 1190 || Loss: 5.8790 || 10iter: 10.6493 sec.
# 迭代 1200 || Loss: 5.2903 || 10iter: 10.4106 sec.
# 迭代 1210 || Loss: 5.9244 || 10iter: 10.7300 sec.
# 迭代 1220 || Loss: 5.5489 || 10iter: 10.6913 sec.
# 迭代 1230 || Loss: 6.0454 || 10iter: 10.7010 sec.
# 迭代 1240 || Loss: 5.5357 || 10iter: 10.8159 sec.
# 迭代 1250 || Loss: 5.7742 || 10iter: 10.8917 sec.
# -------------
# epoch 7 || Epoch_TRAIN_Loss:1006.5686 ||Epoch_VAL_Loss:0.0000
# timer:  197.4693 sec.
# -------------
# Epoch 8/50
# -------------
# （train）
# 迭代 1260 || Loss: 5.3816 || 10iter: 7.4610 sec.
# 迭代 1270 || Loss: 5.8460 || 10iter: 11.0480 sec.
# 迭代 1280 || Loss: 5.3812 || 10iter: 11.1492 sec.
# 迭代 1290 || Loss: 5.1893 || 10iter: 10.6611 sec.
# 迭代 1300 || Loss: 5.4647 || 10iter: 10.6697 sec.
# 迭代 1310 || Loss: 5.2636 || 10iter: 10.8203 sec.
# 迭代 1320 || Loss: 5.2659 || 10iter: 10.5039 sec.
# 迭代 1330 || Loss: 5.6065 || 10iter: 11.0567 sec.
# 迭代 1340 || Loss: 5.3662 || 10iter: 10.8202 sec.
# 迭代 1350 || Loss: 5.7876 || 10iter: 10.8323 sec.
# 迭代 1360 || Loss: 5.4816 || 10iter: 10.7345 sec.
# 迭代 1370 || Loss: 4.9755 || 10iter: 10.8301 sec.
# 迭代 1380 || Loss: 5.4567 || 10iter: 10.5608 sec.
# 迭代 1390 || Loss: 5.4838 || 10iter: 10.9043 sec.
# 迭代 1400 || Loss: 5.2813 || 10iter: 10.6481 sec.
# 迭代 1410 || Loss: 5.8002 || 10iter: 10.5297 sec.
# 迭代 1420 || Loss: 5.1761 || 10iter: 10.4797 sec.
# 迭代 1430 || Loss: 5.6056 || 10iter: 10.4789 sec.
# -------------
# epoch 8 || Epoch_TRAIN_Loss:970.7273 ||Epoch_VAL_Loss:0.0000
# timer:  198.2889 sec.
# -------------
# Epoch 9/50
# -------------
# （train）
# 迭代 1440 || Loss: 5.5713 || 10iter: 8.5154 sec.
# 迭代 1450 || Loss: 5.1546 || 10iter: 10.7467 sec.
# 迭代 1460 || Loss: 5.3310 || 10iter: 10.6863 sec.
# 迭代 1470 || Loss: 5.5728 || 10iter: 10.6986 sec.
# 迭代 1480 || Loss: 5.4541 || 10iter: 10.8122 sec.
# 迭代 1490 || Loss: 4.8327 || 10iter: 10.7661 sec.
# 迭代 1500 || Loss: 5.5772 || 10iter: 11.1505 sec.
# 迭代 1510 || Loss: 5.0786 || 10iter: 10.7509 sec.
# 迭代 1520 || Loss: 5.1306 || 10iter: 10.7322 sec.
# 迭代 1530 || Loss: 5.3322 || 10iter: 10.5874 sec.
# 迭代 1540 || Loss: 5.4941 || 10iter: 10.9784 sec.
# 迭代 1550 || Loss: 5.1622 || 10iter: 11.0489 sec.
# 迭代 1560 || Loss: 5.4221 || 10iter: 10.9678 sec.
# 迭代 1570 || Loss: 5.7243 || 10iter: 10.9991 sec.
# 迭代 1580 || Loss: 5.3503 || 10iter: 10.8679 sec.
# 迭代 1590 || Loss: 5.1598 || 10iter: 10.7829 sec.
# 迭代 1600 || Loss: 5.1718 || 10iter: 10.8915 sec.
# 迭代 1610 || Loss: 5.3772 || 10iter: 11.0988 sec.
# -------------
# epoch 9 || Epoch_TRAIN_Loss:940.6484 ||Epoch_VAL_Loss:0.0000
# timer:  200.1764 sec.
# -------------
# Epoch 10/50
# -------------
# （train）
# 迭代 1620 || Loss: 5.4612 || 10iter: 9.5484 sec.
# 迭代 1630 || Loss: 5.1457 || 10iter: 10.4505 sec.
# 迭代 1640 || Loss: 5.4440 || 10iter: 10.6550 sec.
# 迭代 1650 || Loss: 5.1227 || 10iter: 10.7571 sec.
# 迭代 1660 || Loss: 5.1654 || 10iter: 10.4766 sec.
# 迭代 1670 || Loss: 5.3986 || 10iter: 10.4329 sec.
# 迭代 1680 || Loss: 5.3424 || 10iter: 10.3151 sec.
# 迭代 1690 || Loss: 5.2292 || 10iter: 10.2020 sec.
# 迭代 1700 || Loss: 5.0106 || 10iter: 10.5183 sec.
# 迭代 1710 || Loss: 5.0408 || 10iter: 10.7401 sec.
# 迭代 1720 || Loss: 4.6499 || 10iter: 10.3109 sec.
# 迭代 1730 || Loss: 5.3154 || 10iter: 10.2089 sec.
# 迭代 1740 || Loss: 5.5422 || 10iter: 10.1811 sec.
# 迭代 1750 || Loss: 5.1364 || 10iter: 10.4084 sec.
# 迭代 1760 || Loss: 5.5731 || 10iter: 10.4953 sec.
# 迭代 1770 || Loss: 5.1705 || 10iter: 10.6663 sec.
# 迭代 1780 || Loss: 4.6852 || 10iter: 10.4249 sec.
# 迭代 1790 || Loss: 5.0595 || 10iter: 10.1758 sec.
# -------------
# （val）
# -------------
# epoch 10 || Epoch_TRAIN_Loss:923.3882 ||Epoch_VAL_Loss:933.7478
# timer:  376.7863 sec.
# -------------
# Epoch 11/50
# -------------
# （train）
# 迭代 1800 || Loss: 4.5932 || 10iter: 10.7263 sec.
# 迭代 1810 || Loss: 5.1168 || 10iter: 10.6548 sec.
# 迭代 1820 || Loss: 5.0737 || 10iter: 10.7561 sec.
# 迭代 1830 || Loss: 5.1530 || 10iter: 10.6679 sec.
# 迭代 1840 || Loss: 5.2319 || 10iter: 10.6637 sec.
# 迭代 1850 || Loss: 4.6356 || 10iter: 10.6092 sec.
# 迭代 1860 || Loss: 4.6549 || 10iter: 10.9205 sec.
# 迭代 1870 || Loss: 5.2318 || 10iter: 10.8643 sec.
# 迭代 1880 || Loss: 4.6641 || 10iter: 10.3670 sec.
# 迭代 1890 || Loss: 4.6631 || 10iter: 10.6686 sec.
# 迭代 1900 || Loss: 4.7757 || 10iter: 10.4213 sec.
# 迭代 1910 || Loss: 4.6125 || 10iter: 10.8129 sec.
# 迭代 1920 || Loss: 5.0978 || 10iter: 10.5113 sec.
# 迭代 1930 || Loss: 5.0480 || 10iter: 10.4542 sec.
# 迭代 1940 || Loss: 4.5416 || 10iter: 10.3283 sec.
# 迭代 1950 || Loss: 5.0506 || 10iter: 10.3542 sec.
# 迭代 1960 || Loss: 4.7345 || 10iter: 10.3790 sec.
# -------------
# epoch 11 || Epoch_TRAIN_Loss:902.9023 ||Epoch_VAL_Loss:0.0000
# timer:  195.3901 sec.
# -------------
# Epoch 12/50
# -------------
# （train）
# 迭代 1970 || Loss: 4.8677 || 10iter: 0.7909 sec.
# 迭代 1980 || Loss: 4.7666 || 10iter: 10.6440 sec.
# 迭代 1990 || Loss: 5.6142 || 10iter: 10.6329 sec.
# 迭代 2000 || Loss: 4.7940 || 10iter: 10.4500 sec.
# 迭代 2010 || Loss: 4.4150 || 10iter: 10.6383 sec.
# 迭代 2020 || Loss: 4.7841 || 10iter: 11.7376 sec.
# 迭代 2030 || Loss: 4.5020 || 10iter: 11.2838 sec.
# 迭代 2040 || Loss: 4.8793 || 10iter: 11.0528 sec.
# 迭代 2050 || Loss: 5.4921 || 10iter: 11.0174 sec.
# 迭代 2060 || Loss: 5.0539 || 10iter: 10.9522 sec.
# 迭代 2070 || Loss: 5.1211 || 10iter: 11.0071 sec.
# 迭代 2080 || Loss: 4.7526 || 10iter: 10.6052 sec.
# 迭代 2090 || Loss: 4.4428 || 10iter: 10.5771 sec.
# 迭代 2100 || Loss: 4.9841 || 10iter: 10.6535 sec.
# 迭代 2110 || Loss: 5.0272 || 10iter: 10.7866 sec.
# 迭代 2120 || Loss: 4.5403 || 10iter: 10.2624 sec.
# 迭代 2130 || Loss: 5.1648 || 10iter: 10.4305 sec.
# 迭代 2140 || Loss: 5.0192 || 10iter: 10.4186 sec.
# -------------
# epoch 12 || Epoch_TRAIN_Loss:885.1652 ||Epoch_VAL_Loss:0.0000
# timer:  198.8994 sec.
# -------------
# Epoch 13/50
# -------------
# （train）
# 迭代 2150 || Loss: 5.2463 || 10iter: 1.8408 sec.
# 迭代 2160 || Loss: 4.8859 || 10iter: 10.7533 sec.
# 迭代 2170 || Loss: 4.6961 || 10iter: 10.6008 sec.
# 迭代 2180 || Loss: 5.2694 || 10iter: 10.4047 sec.
# 迭代 2190 || Loss: 5.1589 || 10iter: 10.4626 sec.
# 迭代 2200 || Loss: 4.6602 || 10iter: 10.3255 sec.
# 迭代 2210 || Loss: 4.5999 || 10iter: 10.3880 sec.
# 迭代 2220 || Loss: 5.2230 || 10iter: 10.7209 sec.
# 迭代 2230 || Loss: 4.3794 || 10iter: 10.4801 sec.
# 迭代 2240 || Loss: 5.0545 || 10iter: 10.8452 sec.
# 迭代 2250 || Loss: 5.0500 || 10iter: 10.6936 sec.
# 迭代 2260 || Loss: 4.8056 || 10iter: 10.7854 sec.
# 迭代 2270 || Loss: 5.1851 || 10iter: 10.8018 sec.
# 迭代 2280 || Loss: 5.0365 || 10iter: 10.4243 sec.
# 迭代 2290 || Loss: 4.9484 || 10iter: 10.6336 sec.
# 迭代 2300 || Loss: 4.7638 || 10iter: 10.7012 sec.
# 迭代 2310 || Loss: 4.8608 || 10iter: 10.7682 sec.
# 迭代 2320 || Loss: 4.7510 || 10iter: 10.3400 sec.
# -------------
# epoch 13 || Epoch_TRAIN_Loss:874.4725 ||Epoch_VAL_Loss:0.0000
# timer:  195.5883 sec.
# -------------
# Epoch 14/50
# -------------
# （train）
# 迭代 2330 || Loss: 4.9557 || 10iter: 3.0360 sec.
# 迭代 2340 || Loss: 4.8180 || 10iter: 10.7461 sec.
# 迭代 2350 || Loss: 4.3213 || 10iter: 10.1194 sec.
# 迭代 2360 || Loss: 5.0017 || 10iter: 10.6476 sec.
# 迭代 2370 || Loss: 4.7811 || 10iter: 10.6822 sec.
# 迭代 2380 || Loss: 4.6992 || 10iter: 10.7613 sec.
# 迭代 2390 || Loss: 4.9225 || 10iter: 10.5570 sec.
# 迭代 2400 || Loss: 4.4070 || 10iter: 10.4280 sec.
# 迭代 2410 || Loss: 4.5427 || 10iter: 10.4598 sec.
# 迭代 2420 || Loss: 4.9394 || 10iter: 10.2856 sec.
# 迭代 2430 || Loss: 5.0666 || 10iter: 10.6240 sec.
# 迭代 2440 || Loss: 5.2542 || 10iter: 10.6341 sec.
# 迭代 2450 || Loss: 4.7149 || 10iter: 10.4648 sec.
# 迭代 2460 || Loss: 4.6081 || 10iter: 10.5447 sec.
# 迭代 2470 || Loss: 5.1272 || 10iter: 10.6770 sec.
# 迭代 2480 || Loss: 4.4527 || 10iter: 10.7561 sec.
# 迭代 2490 || Loss: 4.6671 || 10iter: 11.0108 sec.
# 迭代 2500 || Loss: 5.1967 || 10iter: 10.7717 sec.
# -------------
# epoch 14 || Epoch_TRAIN_Loss:851.3259 ||Epoch_VAL_Loss:0.0000
# timer:  195.6441 sec.
# -------------
# Epoch 15/50
# -------------
# （train）
# 迭代 2510 || Loss: 4.0392 || 10iter: 3.9513 sec.
# 迭代 2520 || Loss: 4.5693 || 10iter: 10.5786 sec.
# 迭代 2530 || Loss: 5.1895 || 10iter: 10.8627 sec.
# 迭代 2540 || Loss: 5.1317 || 10iter: 10.3820 sec.
# 迭代 2550 || Loss: 4.5390 || 10iter: 10.7675 sec.
# 迭代 2560 || Loss: 4.5706 || 10iter: 10.6761 sec.
# 迭代 2570 || Loss: 4.0261 || 10iter: 11.5917 sec.
# 迭代 2580 || Loss: 4.9456 || 10iter: 11.8710 sec.
# 迭代 2590 || Loss: 4.4017 || 10iter: 11.6460 sec.
# 迭代 2600 || Loss: 4.0066 || 10iter: 11.7927 sec.
# 迭代 2610 || Loss: 4.7769 || 10iter: 11.2495 sec.
# 迭代 2620 || Loss: 5.0030 || 10iter: 11.1360 sec.
# 迭代 2630 || Loss: 4.8983 || 10iter: 11.3365 sec.
# 迭代 2640 || Loss: 4.3419 || 10iter: 11.1346 sec.
# 迭代 2650 || Loss: 4.3907 || 10iter: 11.1031 sec.
# 迭代 2660 || Loss: 4.0681 || 10iter: 11.3480 sec.
# 迭代 2670 || Loss: 4.5468 || 10iter: 11.1598 sec.
# 迭代 2680 || Loss: 4.7242 || 10iter: 10.2853 sec.
# -------------
# epoch 15 || Epoch_TRAIN_Loss:833.9012 ||Epoch_VAL_Loss:0.0000
# timer:  204.2008 sec.
# -------------
# Epoch 16/50
# -------------
# （train）
# 迭代 2690 || Loss: 4.7274 || 10iter: 5.1215 sec.
# 迭代 2700 || Loss: 5.1510 || 10iter: 10.4765 sec.
# 迭代 2710 || Loss: 4.2696 || 10iter: 10.5485 sec.
# 迭代 2720 || Loss: 4.4225 || 10iter: 10.4580 sec.
# 迭代 2730 || Loss: 4.8483 || 10iter: 10.6090 sec.
# 迭代 2740 || Loss: 4.2436 || 10iter: 10.5465 sec.
# 迭代 2750 || Loss: 4.4585 || 10iter: 10.6549 sec.
# 迭代 2760 || Loss: 4.9234 || 10iter: 10.5597 sec.
# 迭代 2770 || Loss: 5.4753 || 10iter: 10.7456 sec.
# 迭代 2780 || Loss: 4.7450 || 10iter: 10.5634 sec.
# 迭代 2790 || Loss: 4.5371 || 10iter: 10.2070 sec.
# 迭代 2800 || Loss: 4.3746 || 10iter: 10.3790 sec.
# 迭代 2810 || Loss: 4.3285 || 10iter: 10.4334 sec.
# 迭代 2820 || Loss: 4.9290 || 10iter: 10.2940 sec.
# 迭代 2830 || Loss: 4.7610 || 10iter: 10.1769 sec.
# 迭代 2840 || Loss: 4.4774 || 10iter: 10.4089 sec.
# 迭代 2850 || Loss: 5.1106 || 10iter: 10.5473 sec.
# 迭代 2860 || Loss: 4.4366 || 10iter: 10.6168 sec.
# -------------
# epoch 16 || Epoch_TRAIN_Loss:821.5931 ||Epoch_VAL_Loss:0.0000
# timer:  194.5038 sec.
# -------------
# Epoch 17/50
# -------------
# （train）
# 迭代 2870 || Loss: 4.6120 || 10iter: 6.2932 sec.
# 迭代 2880 || Loss: 4.6141 || 10iter: 10.3851 sec.
# 迭代 2890 || Loss: 4.3079 || 10iter: 10.3010 sec.
# 迭代 2900 || Loss: 4.4198 || 10iter: 10.5598 sec.
# 迭代 2910 || Loss: 4.4209 || 10iter: 10.2763 sec.
# 迭代 2920 || Loss: 4.3516 || 10iter: 10.4002 sec.
# 迭代 2930 || Loss: 4.3231 || 10iter: 10.1754 sec.
# 迭代 2940 || Loss: 4.5192 || 10iter: 10.3926 sec.
# 迭代 2950 || Loss: 4.5849 || 10iter: 10.9041 sec.
# 迭代 2960 || Loss: 4.9856 || 10iter: 10.6213 sec.
# 迭代 2970 || Loss: 4.3298 || 10iter: 10.7270 sec.
# 迭代 2980 || Loss: 4.7020 || 10iter: 10.5036 sec.
# 迭代 2990 || Loss: 4.6549 || 10iter: 10.2958 sec.
# 迭代 3000 || Loss: 4.5153 || 10iter: 10.8997 sec.
# 迭代 3010 || Loss: 4.7496 || 10iter: 10.9470 sec.
# 迭代 3020 || Loss: 4.7830 || 10iter: 11.0400 sec.
# 迭代 3030 || Loss: 4.5693 || 10iter: 10.9851 sec.
# 迭代 3040 || Loss: 4.3680 || 10iter: 10.7087 sec.
# -------------
# epoch 17 || Epoch_TRAIN_Loss:819.6218 ||Epoch_VAL_Loss:0.0000
# timer:  195.5188 sec.
# -------------
# Epoch 18/50
# -------------
# （train）
# 迭代 3050 || Loss: 4.0927 || 10iter: 7.2793 sec.
# 迭代 3060 || Loss: 4.6411 || 10iter: 10.9830 sec.
# 迭代 3070 || Loss: 4.5559 || 10iter: 11.0118 sec.
# 迭代 3080 || Loss: 4.3162 || 10iter: 10.5963 sec.
# 迭代 3090 || Loss: 4.8999 || 10iter: 10.4299 sec.
# 迭代 3100 || Loss: 4.5340 || 10iter: 10.5000 sec.
# 迭代 3110 || Loss: 3.9540 || 10iter: 10.7347 sec.
# 迭代 3120 || Loss: 4.8944 || 10iter: 10.6200 sec.
# 迭代 3130 || Loss: 4.4225 || 10iter: 10.6766 sec.
# 迭代 3140 || Loss: 4.9447 || 10iter: 10.6707 sec.
# 迭代 3150 || Loss: 4.5313 || 10iter: 10.5770 sec.
# 迭代 3160 || Loss: 4.2294 || 10iter: 10.6013 sec.
# 迭代 3170 || Loss: 5.0599 || 10iter: 10.5349 sec.
# 迭代 3180 || Loss: 4.6164 || 10iter: 10.5990 sec.
# 迭代 3190 || Loss: 4.2735 || 10iter: 10.6983 sec.
# 迭代 3200 || Loss: 4.3384 || 10iter: 10.3291 sec.
# 迭代 3210 || Loss: 4.6672 || 10iter: 10.5806 sec.
# 迭代 3220 || Loss: 4.2793 || 10iter: 10.9908 sec.
# -------------
# epoch 18 || Epoch_TRAIN_Loss:806.9385 ||Epoch_VAL_Loss:0.0000
# timer:  196.6237 sec.
# -------------
# Epoch 19/50
# -------------
# （train）
# 迭代 3230 || Loss: 4.1159 || 10iter: 8.4907 sec.
# 迭代 3240 || Loss: 3.9852 || 10iter: 10.4859 sec.
# 迭代 3250 || Loss: 4.6243 || 10iter: 10.3396 sec.
# 迭代 3260 || Loss: 4.0898 || 10iter: 10.5030 sec.
# 迭代 3270 || Loss: 4.3530 || 10iter: 10.1952 sec.
# 迭代 3280 || Loss: 4.5037 || 10iter: 10.3978 sec.
# 迭代 3290 || Loss: 4.2442 || 10iter: 10.3006 sec.
# 迭代 3300 || Loss: 4.7905 || 10iter: 10.4913 sec.
# 迭代 3310 || Loss: 4.5802 || 10iter: 10.5743 sec.
# 迭代 3320 || Loss: 4.5994 || 10iter: 10.6378 sec.
# 迭代 3330 || Loss: 3.8048 || 10iter: 10.5108 sec.
# 迭代 3340 || Loss: 4.5558 || 10iter: 10.6540 sec.
# 迭代 3350 || Loss: 4.8849 || 10iter: 10.7605 sec.
# 迭代 3360 || Loss: 4.3028 || 10iter: 10.4078 sec.
# 迭代 3370 || Loss: 3.8040 || 10iter: 10.6976 sec.
# 迭代 3380 || Loss: 4.2887 || 10iter: 10.6118 sec.
# 迭代 3390 || Loss: 4.2023 || 10iter: 10.4446 sec.
# 迭代 3400 || Loss: 4.6182 || 10iter: 10.7403 sec.
# -------------
# epoch 19 || Epoch_TRAIN_Loss:785.8683 ||Epoch_VAL_Loss:0.0000
# timer:  194.3564 sec.
# -------------
# Epoch 20/50
# -------------
# （train）
# 迭代 3410 || Loss: 4.3897 || 10iter: 9.3864 sec.
# 迭代 3420 || Loss: 4.5207 || 10iter: 10.6433 sec.
# 迭代 3430 || Loss: 4.1183 || 10iter: 10.4307 sec.
# 迭代 3440 || Loss: 4.4747 || 10iter: 10.6747 sec.
# 迭代 3450 || Loss: 4.1956 || 10iter: 10.8582 sec.
# 迭代 3460 || Loss: 4.1952 || 10iter: 10.6751 sec.
# 迭代 3470 || Loss: 4.4614 || 10iter: 10.5877 sec.
# 迭代 3480 || Loss: 4.9353 || 10iter: 10.6501 sec.
# 迭代 3490 || Loss: 4.5446 || 10iter: 10.8151 sec.
# 迭代 3500 || Loss: 4.7273 || 10iter: 10.4608 sec.
# 迭代 3510 || Loss: 4.7946 || 10iter: 10.2150 sec.
# 迭代 3520 || Loss: 3.9509 || 10iter: 10.7478 sec.
# 迭代 3530 || Loss: 3.9941 || 10iter: 10.5880 sec.
# 迭代 3540 || Loss: 4.5269 || 10iter: 10.4830 sec.
# 迭代 3550 || Loss: 4.8651 || 10iter: 10.7163 sec.
# 迭代 3560 || Loss: 4.0535 || 10iter: 10.7516 sec.
# 迭代 3570 || Loss: 4.5866 || 10iter: 10.4353 sec.
# 迭代 3580 || Loss: 4.4897 || 10iter: 10.2147 sec.
# -------------
# （val）
# -------------
# epoch 20 || Epoch_TRAIN_Loss:778.6638 ||Epoch_VAL_Loss:816.3696
# timer:  276.9053 sec.
# -------------
# Epoch 21/50
# -------------
# （train）
# 迭代 3590 || Loss: 4.5667 || 10iter: 10.9808 sec.
# 迭代 3600 || Loss: 4.3183 || 10iter: 10.8035 sec.
# 迭代 3610 || Loss: 4.7082 || 10iter: 10.5219 sec.
# 迭代 3620 || Loss: 4.4990 || 10iter: 10.4609 sec.
# 迭代 3630 || Loss: 4.3774 || 10iter: 10.2570 sec.
# 迭代 3640 || Loss: 4.6198 || 10iter: 10.5122 sec.
# 迭代 3650 || Loss: 4.5481 || 10iter: 10.6151 sec.
# 迭代 3660 || Loss: 3.8261 || 10iter: 10.6881 sec.
# 迭代 3670 || Loss: 5.0179 || 10iter: 10.5456 sec.
# 迭代 3680 || Loss: 4.4086 || 10iter: 10.7555 sec.
# 迭代 3690 || Loss: 4.3684 || 10iter: 10.4671 sec.
# 迭代 3700 || Loss: 4.4459 || 10iter: 10.7422 sec.
# 迭代 3710 || Loss: 4.1419 || 10iter: 11.1345 sec.
# 迭代 3720 || Loss: 4.3369 || 10iter: 10.7847 sec.
# 迭代 3730 || Loss: 4.7005 || 10iter: 10.6662 sec.
# 迭代 3740 || Loss: 4.5862 || 10iter: 10.7148 sec.
# 迭代 3750 || Loss: 4.5223 || 10iter: 10.7887 sec.
# -------------
# epoch 21 || Epoch_TRAIN_Loss:773.0728 ||Epoch_VAL_Loss:0.0000
# timer:  196.9982 sec.
# -------------
# Epoch 22/50
# -------------
# （train）
# 迭代 3760 || Loss: 3.6752 || 10iter: 0.7420 sec.
# 迭代 3770 || Loss: 4.6687 || 10iter: 10.7647 sec.
# 迭代 3780 || Loss: 3.7362 || 10iter: 10.5885 sec.
# 迭代 3790 || Loss: 4.3233 || 10iter: 10.9653 sec.
# 迭代 3800 || Loss: 4.1502 || 10iter: 11.0686 sec.
# 迭代 3810 || Loss: 4.0366 || 10iter: 10.5936 sec.
# 迭代 3820 || Loss: 4.3934 || 10iter: 10.9519 sec.
# 迭代 3830 || Loss: 4.1028 || 10iter: 10.4882 sec.
# 迭代 3840 || Loss: 5.0208 || 10iter: 10.6672 sec.
# 迭代 3850 || Loss: 4.3573 || 10iter: 10.8402 sec.
# 迭代 3860 || Loss: 4.0090 || 10iter: 10.8739 sec.
# 迭代 3870 || Loss: 4.3057 || 10iter: 11.0075 sec.
# 迭代 3880 || Loss: 4.2484 || 10iter: 10.5594 sec.
# 迭代 3890 || Loss: 3.6645 || 10iter: 10.2392 sec.
# 迭代 3900 || Loss: 4.3782 || 10iter: 10.5278 sec.
# 迭代 3910 || Loss: 4.0221 || 10iter: 10.5971 sec.
# 迭代 3920 || Loss: 3.9227 || 10iter: 10.4406 sec.
# 迭代 3930 || Loss: 4.1510 || 10iter: 10.6073 sec.
# -------------
# epoch 22 || Epoch_TRAIN_Loss:751.4548 ||Epoch_VAL_Loss:0.0000
# timer:  197.1129 sec.
# -------------
# Epoch 23/50
# -------------
# （train）
# 迭代 3940 || Loss: 3.9662 || 10iter: 1.8743 sec.
# 迭代 3950 || Loss: 4.3271 || 10iter: 10.6631 sec.
# 迭代 3960 || Loss: 4.3001 || 10iter: 10.4127 sec.
# 迭代 3970 || Loss: 4.5396 || 10iter: 10.4301 sec.
# 迭代 3980 || Loss: 4.6632 || 10iter: 10.4966 sec.
# 迭代 3990 || Loss: 4.2108 || 10iter: 10.5459 sec.
# 迭代 4000 || Loss: 4.2439 || 10iter: 10.6077 sec.
# 迭代 4010 || Loss: 4.1152 || 10iter: 10.5552 sec.
# 迭代 4020 || Loss: 4.3678 || 10iter: 10.5237 sec.
# 迭代 4030 || Loss: 3.8405 || 10iter: 10.9059 sec.
# 迭代 4040 || Loss: 4.2293 || 10iter: 10.9615 sec.
# 迭代 4050 || Loss: 4.1591 || 10iter: 10.9991 sec.
# 迭代 4060 || Loss: 4.2936 || 10iter: 10.8284 sec.
# 迭代 4070 || Loss: 4.1209 || 10iter: 10.8619 sec.
# 迭代 4080 || Loss: 3.8213 || 10iter: 10.5310 sec.
# 迭代 4090 || Loss: 4.1574 || 10iter: 10.4052 sec.
# 迭代 4100 || Loss: 4.6400 || 10iter: 10.2098 sec.
# 迭代 4110 || Loss: 4.3381 || 10iter: 10.6278 sec.
# -------------
# epoch 23 || Epoch_TRAIN_Loss:751.2611 ||Epoch_VAL_Loss:0.0000
# timer:  196.4106 sec.
# -------------
# Epoch 24/50
# -------------
# （train）
# 迭代 4120 || Loss: 4.3548 || 10iter: 3.0300 sec.
# 迭代 4130 || Loss: 4.1230 || 10iter: 10.6724 sec.
# 迭代 4140 || Loss: 4.6779 || 10iter: 10.6103 sec.
# 迭代 4150 || Loss: 4.4243 || 10iter: 10.8746 sec.
# 迭代 4160 || Loss: 4.2587 || 10iter: 10.4383 sec.
# 迭代 4170 || Loss: 4.0928 || 10iter: 10.8210 sec.
# 迭代 4180 || Loss: 3.8822 || 10iter: 10.4420 sec.
# 迭代 4190 || Loss: 4.1716 || 10iter: 10.5394 sec.
# 迭代 4200 || Loss: 3.7609 || 10iter: 10.0657 sec.
# 迭代 4210 || Loss: 4.6400 || 10iter: 10.2378 sec.
# 迭代 4220 || Loss: 4.5198 || 10iter: 10.5167 sec.
# 迭代 4230 || Loss: 4.4465 || 10iter: 10.4126 sec.
# 迭代 4240 || Loss: 4.1669 || 10iter: 10.6763 sec.
# 迭代 4250 || Loss: 4.0523 || 10iter: 10.9407 sec.
# 迭代 4260 || Loss: 3.7727 || 10iter: 10.6853 sec.
# 迭代 4270 || Loss: 4.3313 || 10iter: 10.7319 sec.
# 迭代 4280 || Loss: 4.2575 || 10iter: 11.0467 sec.
# 迭代 4290 || Loss: 4.4070 || 10iter: 10.7574 sec.
# -------------
# epoch 24 || Epoch_TRAIN_Loss:740.3007 ||Epoch_VAL_Loss:0.0000
# timer:  196.2484 sec.
# -------------
# Epoch 25/50
# -------------
# （train）
# 迭代 4300 || Loss: 3.8827 || 10iter: 4.2605 sec.
# 迭代 4310 || Loss: 4.2568 || 10iter: 10.6428 sec.
# 迭代 4320 || Loss: 4.3261 || 10iter: 11.1076 sec.
# 迭代 4330 || Loss: 3.6524 || 10iter: 12.1746 sec.
# 迭代 4340 || Loss: 3.7899 || 10iter: 10.7856 sec.
# 迭代 4350 || Loss: 3.8692 || 10iter: 10.8524 sec.
# 迭代 4360 || Loss: 4.3159 || 10iter: 10.8777 sec.
# 迭代 4370 || Loss: 3.7144 || 10iter: 10.7653 sec.
# 迭代 4380 || Loss: 4.2732 || 10iter: 11.0392 sec.
# 迭代 4390 || Loss: 4.3162 || 10iter: 10.8393 sec.
# 迭代 4400 || Loss: 3.9883 || 10iter: 10.2837 sec.
# 迭代 4410 || Loss: 4.5676 || 10iter: 10.5963 sec.
# 迭代 4420 || Loss: 3.6543 || 10iter: 10.1439 sec.
# 迭代 4430 || Loss: 3.9632 || 10iter: 10.5708 sec.
# 迭代 4440 || Loss: 4.2760 || 10iter: 10.6439 sec.
# 迭代 4450 || Loss: 4.1533 || 10iter: 10.8645 sec.
# 迭代 4460 || Loss: 4.1590 || 10iter: 11.1285 sec.
# 迭代 4470 || Loss: 3.8771 || 10iter: 10.5608 sec.
# -------------
# epoch 25 || Epoch_TRAIN_Loss:735.9341 ||Epoch_VAL_Loss:0.0000
# timer:  199.9807 sec.
# -------------
# Epoch 26/50
# -------------
# （train）
# 迭代 4480 || Loss: 4.1090 || 10iter: 5.2078 sec.
# 迭代 4490 || Loss: 3.9414 || 10iter: 10.6386 sec.
# 迭代 4500 || Loss: 4.3323 || 10iter: 10.6649 sec.
# 迭代 4510 || Loss: 3.8638 || 10iter: 10.5380 sec.
# 迭代 4520 || Loss: 3.8814 || 10iter: 10.7839 sec.
# 迭代 4530 || Loss: 4.5271 || 10iter: 10.5394 sec.
# 迭代 4540 || Loss: 4.2143 || 10iter: 10.7634 sec.
# 迭代 4550 || Loss: 4.4886 || 10iter: 10.5713 sec.
# 迭代 4560 || Loss: 3.5391 || 10iter: 10.5035 sec.
# 迭代 4570 || Loss: 4.2979 || 10iter: 10.5835 sec.
# 迭代 4580 || Loss: 3.9670 || 10iter: 10.4491 sec.
# 迭代 4590 || Loss: 3.7646 || 10iter: 10.2717 sec.
# 迭代 4600 || Loss: 3.8790 || 10iter: 10.3525 sec.
# 迭代 4610 || Loss: 4.2390 || 10iter: 10.3817 sec.
# 迭代 4620 || Loss: 4.0782 || 10iter: 10.3901 sec.
# 迭代 4630 || Loss: 3.9936 || 10iter: 10.5062 sec.
# 迭代 4640 || Loss: 4.0724 || 10iter: 10.6180 sec.
# 迭代 4650 || Loss: 3.3629 || 10iter: 10.7799 sec.
# -------------
# epoch 26 || Epoch_TRAIN_Loss:723.2048 ||Epoch_VAL_Loss:0.0000
# timer:  194.8864 sec.
# -------------
# Epoch 27/50
# -------------
# （train）
# 迭代 4660 || Loss: 3.9663 || 10iter: 6.0543 sec.
# 迭代 4670 || Loss: 3.8935 || 10iter: 10.3323 sec.
# 迭代 4680 || Loss: 3.7275 || 10iter: 10.6557 sec.
# 迭代 4690 || Loss: 3.9407 || 10iter: 10.4964 sec.
# 迭代 4700 || Loss: 3.9658 || 10iter: 10.3230 sec.
# 迭代 4710 || Loss: 4.1819 || 10iter: 10.4551 sec.
# 迭代 4720 || Loss: 3.8325 || 10iter: 10.4208 sec.
# 迭代 4730 || Loss: 4.1878 || 10iter: 10.5135 sec.
# 迭代 4740 || Loss: 4.0551 || 10iter: 10.5451 sec.
# 迭代 4750 || Loss: 3.7872 || 10iter: 10.6210 sec.
# 迭代 4760 || Loss: 3.3549 || 10iter: 10.3073 sec.
# 迭代 4770 || Loss: 4.2633 || 10iter: 10.9739 sec.
# 迭代 4780 || Loss: 3.8921 || 10iter: 10.4189 sec.
# 迭代 4790 || Loss: 4.2049 || 10iter: 10.3724 sec.
# 迭代 4800 || Loss: 3.8503 || 10iter: 10.4469 sec.
# 迭代 4810 || Loss: 3.7911 || 10iter: 10.7550 sec.
# 迭代 4820 || Loss: 4.0847 || 10iter: 11.0118 sec.
# 迭代 4830 || Loss: 3.8631 || 10iter: 10.6573 sec.
# -------------
# epoch 27 || Epoch_TRAIN_Loss:720.1192 ||Epoch_VAL_Loss:0.0000
# timer:  194.4916 sec.
# -------------
# Epoch 28/50
# -------------
# （train）
# 迭代 4840 || Loss: 3.7010 || 10iter: 7.6813 sec.
# 迭代 4850 || Loss: 4.1632 || 10iter: 10.2662 sec.
# 迭代 4860 || Loss: 3.7675 || 10iter: 10.7025 sec.
# 迭代 4870 || Loss: 4.0728 || 10iter: 11.3363 sec.
# 迭代 4880 || Loss: 3.9611 || 10iter: 10.7561 sec.
# 迭代 4890 || Loss: 3.8638 || 10iter: 10.6921 sec.
# 迭代 4900 || Loss: 3.3148 || 10iter: 10.4231 sec.
# 迭代 4910 || Loss: 4.2159 || 10iter: 10.6718 sec.
# 迭代 4920 || Loss: 3.9970 || 10iter: 10.7308 sec.
# 迭代 4930 || Loss: 4.2867 || 10iter: 10.5530 sec.
# 迭代 4940 || Loss: 4.3496 || 10iter: 10.2939 sec.
# 迭代 4950 || Loss: 3.7498 || 10iter: 10.6939 sec.
# 迭代 4960 || Loss: 3.8510 || 10iter: 10.7930 sec.
# 迭代 4970 || Loss: 3.5222 || 10iter: 10.8965 sec.
# 迭代 4980 || Loss: 3.7071 || 10iter: 11.2467 sec.
# 迭代 4990 || Loss: 3.8360 || 10iter: 10.5836 sec.
# 迭代 5000 || Loss: 3.8237 || 10iter: 10.7602 sec.
# 迭代 5010 || Loss: 3.6653 || 10iter: 11.0909 sec.
# -------------
# epoch 28 || Epoch_TRAIN_Loss:712.6570 ||Epoch_VAL_Loss:0.0000
# timer:  198.2399 sec.
# -------------
# Epoch 29/50
# -------------
# （train）
# 迭代 5020 || Loss: 4.5778 || 10iter: 8.3099 sec.
# 迭代 5030 || Loss: 3.8579 || 10iter: 11.1131 sec.
# 迭代 5040 || Loss: 3.2781 || 10iter: 11.0048 sec.
# 迭代 5050 || Loss: 4.0888 || 10iter: 10.6274 sec.
# 迭代 5060 || Loss: 3.7566 || 10iter: 10.4326 sec.
# 迭代 5070 || Loss: 4.1975 || 10iter: 10.7717 sec.
# 迭代 5080 || Loss: 3.7378 || 10iter: 10.8960 sec.
# 迭代 5090 || Loss: 3.3778 || 10iter: 10.8523 sec.
# 迭代 5100 || Loss: 4.2111 || 10iter: 10.3277 sec.
# 迭代 5110 || Loss: 4.2191 || 10iter: 10.7262 sec.
# 迭代 5120 || Loss: 4.3775 || 10iter: 10.6403 sec.
# 迭代 5130 || Loss: 4.1298 || 10iter: 10.6803 sec.
# 迭代 5140 || Loss: 3.7178 || 10iter: 10.6384 sec.
# 迭代 5150 || Loss: 3.6772 || 10iter: 10.8794 sec.
# 迭代 5160 || Loss: 4.0021 || 10iter: 10.7063 sec.
# 迭代 5170 || Loss: 4.1865 || 10iter: 10.4372 sec.
# 迭代 5180 || Loss: 3.6868 || 10iter: 10.7080 sec.
# 迭代 5190 || Loss: 3.3793 || 10iter: 10.8481 sec.
# -------------
# epoch 29 || Epoch_TRAIN_Loss:705.2023 ||Epoch_VAL_Loss:0.0000
# timer:  197.5491 sec.
# -------------
# Epoch 30/50
# -------------
# （train）
# 迭代 5200 || Loss: 3.3567 || 10iter: 9.5068 sec.
# 迭代 5210 || Loss: 4.1752 || 10iter: 10.5720 sec.
# 迭代 5220 || Loss: 3.5128 || 10iter: 10.6821 sec.
# 迭代 5230 || Loss: 3.9030 || 10iter: 10.8707 sec.
# 迭代 5240 || Loss: 3.7321 || 10iter: 10.7047 sec.
# 迭代 5250 || Loss: 3.7084 || 10iter: 10.6046 sec.
# 迭代 5260 || Loss: 3.8411 || 10iter: 10.3232 sec.
# 迭代 5270 || Loss: 4.2437 || 10iter: 10.4934 sec.
# 迭代 5280 || Loss: 4.2554 || 10iter: 10.3372 sec.
# 迭代 5290 || Loss: 3.6586 || 10iter: 10.4088 sec.
# 迭代 5300 || Loss: 3.8231 || 10iter: 10.3993 sec.
# 迭代 5310 || Loss: 4.3439 || 10iter: 10.3523 sec.
# 迭代 5320 || Loss: 4.3143 || 10iter: 10.4830 sec.
# 迭代 5330 || Loss: 3.7409 || 10iter: 10.9013 sec.
# 迭代 5340 || Loss: 3.3312 || 10iter: 10.8474 sec.
# 迭代 5350 || Loss: 3.6137 || 10iter: 10.9239 sec.
# 迭代 5360 || Loss: 3.6137 || 10iter: 10.8985 sec.
# 迭代 5370 || Loss: 3.9185 || 10iter: 10.7965 sec.
# -------------
# （val）
# -------------
# epoch 30 || Epoch_TRAIN_Loss:701.1695 ||Epoch_VAL_Loss:731.6476
# timer:  276.6735 sec.
# -------------
# Epoch 31/50
# -------------
# （train）
# 迭代 5380 || Loss: 3.6825 || 10iter: 10.4515 sec.
# 迭代 5390 || Loss: 3.8285 || 10iter: 10.3604 sec.
# 迭代 5400 || Loss: 4.2689 || 10iter: 10.4723 sec.
# 迭代 5410 || Loss: 3.3611 || 10iter: 10.5525 sec.
# 迭代 5420 || Loss: 4.2259 || 10iter: 10.5016 sec.
# 迭代 5430 || Loss: 3.7860 || 10iter: 10.5638 sec.
# 迭代 5440 || Loss: 3.8099 || 10iter: 10.6793 sec.
# 迭代 5450 || Loss: 4.0450 || 10iter: 10.7581 sec.
# 迭代 5460 || Loss: 2.9234 || 10iter: 10.8824 sec.
# 迭代 5470 || Loss: 3.7720 || 10iter: 11.0168 sec.
# 迭代 5480 || Loss: 3.8608 || 10iter: 10.4536 sec.
# 迭代 5490 || Loss: 4.0541 || 10iter: 10.3703 sec.
# 迭代 5500 || Loss: 4.4059 || 10iter: 11.0241 sec.
# 迭代 5510 || Loss: 4.0479 || 10iter: 11.2872 sec.
# 迭代 5520 || Loss: 4.0825 || 10iter: 10.6838 sec.
# 迭代 5530 || Loss: 3.7770 || 10iter: 10.8264 sec.
# 迭代 5540 || Loss: 3.6815 || 10iter: 10.4944 sec.
# -------------
# epoch 31 || Epoch_TRAIN_Loss:687.8422 ||Epoch_VAL_Loss:0.0000
# timer:  196.8862 sec.
# -------------
# Epoch 32/50
# -------------
# （train）
# 迭代 5550 || Loss: 3.6180 || 10iter: 0.7511 sec.
# 迭代 5560 || Loss: 3.5617 || 10iter: 10.7931 sec.
# 迭代 5570 || Loss: 3.8782 || 10iter: 10.4194 sec.
# 迭代 5580 || Loss: 4.2483 || 10iter: 10.5051 sec.
# 迭代 5590 || Loss: 3.3018 || 10iter: 10.6187 sec.
# 迭代 5600 || Loss: 3.6892 || 10iter: 10.4298 sec.
# 迭代 5610 || Loss: 3.7095 || 10iter: 10.4791 sec.
# 迭代 5620 || Loss: 4.1196 || 10iter: 10.5161 sec.
# 迭代 5630 || Loss: 3.6375 || 10iter: 10.4988 sec.
# 迭代 5640 || Loss: 3.8281 || 10iter: 10.3322 sec.
# 迭代 5650 || Loss: 4.2863 || 10iter: 10.6285 sec.
# 迭代 5660 || Loss: 4.1366 || 10iter: 10.1249 sec.
# 迭代 5670 || Loss: 3.8122 || 10iter: 10.5203 sec.
# 迭代 5680 || Loss: 4.4379 || 10iter: 10.7212 sec.
# 迭代 5690 || Loss: 3.8158 || 10iter: 10.2510 sec.
# 迭代 5700 || Loss: 3.5327 || 10iter: 10.3945 sec.
# 迭代 5710 || Loss: 3.4806 || 10iter: 10.6815 sec.
# 迭代 5720 || Loss: 3.6227 || 10iter: 10.5885 sec.
# -------------
# epoch 32 || Epoch_TRAIN_Loss:690.1855 ||Epoch_VAL_Loss:0.0000
# timer:  193.8079 sec.
# -------------
# Epoch 33/50
# -------------
# （train）
# 迭代 5730 || Loss: 3.6958 || 10iter: 1.7900 sec.
# 迭代 5740 || Loss: 3.2651 || 10iter: 10.2382 sec.
# 迭代 5750 || Loss: 3.5425 || 10iter: 10.2514 sec.
# 迭代 5760 || Loss: 3.4818 || 10iter: 10.4325 sec.
# 迭代 5770 || Loss: 3.7009 || 10iter: 10.1189 sec.
# 迭代 5780 || Loss: 3.5661 || 10iter: 10.4359 sec.
# 迭代 5790 || Loss: 3.8098 || 10iter: 10.3695 sec.
# 迭代 5800 || Loss: 4.1673 || 10iter: 10.6197 sec.
# 迭代 5810 || Loss: 3.7377 || 10iter: 10.7025 sec.
# 迭代 5820 || Loss: 3.8500 || 10iter: 10.1178 sec.
# 迭代 5830 || Loss: 3.7834 || 10iter: 10.7111 sec.
# 迭代 5840 || Loss: 3.6419 || 10iter: 10.4035 sec.
# 迭代 5850 || Loss: 3.6767 || 10iter: 10.5790 sec.
# 迭代 5860 || Loss: 3.3368 || 10iter: 10.4052 sec.
# 迭代 5870 || Loss: 3.5478 || 10iter: 10.4515 sec.
# 迭代 5880 || Loss: 4.3360 || 10iter: 10.5573 sec.
# 迭代 5890 || Loss: 3.6543 || 10iter: 10.5702 sec.
# 迭代 5900 || Loss: 3.8655 || 10iter: 10.3805 sec.
# -------------
# epoch 33 || Epoch_TRAIN_Loss:682.1993 ||Epoch_VAL_Loss:0.0000
# timer:  192.4255 sec.
# -------------
# Epoch 34/50
# -------------
# （train）
# 迭代 5910 || Loss: 3.7111 || 10iter: 2.9447 sec.
# 迭代 5920 || Loss: 4.5779 || 10iter: 10.4795 sec.
# 迭代 5930 || Loss: 3.8686 || 10iter: 10.5319 sec.
# 迭代 5940 || Loss: 3.4155 || 10iter: 10.3382 sec.
# 迭代 5950 || Loss: 4.0956 || 10iter: 10.1315 sec.
# 迭代 5960 || Loss: 3.5844 || 10iter: 10.1772 sec.
# 迭代 5970 || Loss: 3.2935 || 10iter: 10.4683 sec.
# 迭代 5980 || Loss: 3.5625 || 10iter: 10.2496 sec.
# 迭代 5990 || Loss: 3.6999 || 10iter: 10.5230 sec.
# 迭代 6000 || Loss: 3.2116 || 10iter: 10.4188 sec.
# 迭代 6010 || Loss: 3.9553 || 10iter: 10.4863 sec.
# 迭代 6020 || Loss: 3.5626 || 10iter: 10.3164 sec.
# 迭代 6030 || Loss: 3.5233 || 10iter: 10.6707 sec.
# 迭代 6040 || Loss: 3.7553 || 10iter: 10.8216 sec.
# 迭代 6050 || Loss: 3.3581 || 10iter: 11.0117 sec.
# 迭代 6060 || Loss: 3.5318 || 10iter: 10.8590 sec.
# 迭代 6070 || Loss: 3.5889 || 10iter: 10.6410 sec.
# 迭代 6080 || Loss: 4.1353 || 10iter: 10.5476 sec.
# -------------
# epoch 34 || Epoch_TRAIN_Loss:674.6504 ||Epoch_VAL_Loss:0.0000
# timer:  193.8261 sec.
# -------------
# Epoch 35/50
# -------------
# （train）
# 迭代 6090 || Loss: 3.9149 || 10iter: 3.9743 sec.
# 迭代 6100 || Loss: 3.5470 || 10iter: 10.4568 sec.
# 迭代 6110 || Loss: 3.6284 || 10iter: 10.7314 sec.
# 迭代 6120 || Loss: 4.0205 || 10iter: 10.2643 sec.
# 迭代 6130 || Loss: 3.5529 || 10iter: 10.3992 sec.
# 迭代 6140 || Loss: 4.2491 || 10iter: 10.2468 sec.
# 迭代 6150 || Loss: 4.0842 || 10iter: 10.5250 sec.
# 迭代 6160 || Loss: 3.5271 || 10iter: 10.1019 sec.
# 迭代 6170 || Loss: 4.1733 || 10iter: 10.3107 sec.
# 迭代 6180 || Loss: 3.9664 || 10iter: 10.4122 sec.
# 迭代 6190 || Loss: 4.1325 || 10iter: 10.4066 sec.
# 迭代 6200 || Loss: 3.6684 || 10iter: 10.5677 sec.
# 迭代 6210 || Loss: 3.5702 || 10iter: 10.4879 sec.
# 迭代 6220 || Loss: 3.7234 || 10iter: 10.5248 sec.
# 迭代 6230 || Loss: 4.5795 || 10iter: 10.5027 sec.
# 迭代 6240 || Loss: 3.9042 || 10iter: 10.5695 sec.
# 迭代 6250 || Loss: 3.7874 || 10iter: 10.4559 sec.
# 迭代 6260 || Loss: 3.7674 || 10iter: 10.4679 sec.
# -------------
# epoch 35 || Epoch_TRAIN_Loss:677.8669 ||Epoch_VAL_Loss:0.0000
# timer:  192.8310 sec.
# -------------
# Epoch 36/50
# -------------
# （train）
# 迭代 6270 || Loss: 3.8246 || 10iter: 5.0256 sec.
# 迭代 6280 || Loss: 3.6567 || 10iter: 10.1942 sec.
# 迭代 6290 || Loss: 3.5883 || 10iter: 10.4348 sec.
# 迭代 6300 || Loss: 3.6182 || 10iter: 10.3631 sec.
# 迭代 6310 || Loss: 3.8494 || 10iter: 10.3214 sec.
# 迭代 6320 || Loss: 3.0926 || 10iter: 10.3878 sec.
# 迭代 6330 || Loss: 3.5729 || 10iter: 10.2745 sec.
# 迭代 6340 || Loss: 3.5284 || 10iter: 10.3272 sec.
# 迭代 6350 || Loss: 4.0460 || 10iter: 10.3552 sec.
# 迭代 6360 || Loss: 4.2746 || 10iter: 10.4703 sec.
# 迭代 6370 || Loss: 4.0733 || 10iter: 10.3369 sec.
# 迭代 6380 || Loss: 4.2504 || 10iter: 10.5208 sec.
# 迭代 6390 || Loss: 4.0240 || 10iter: 10.3581 sec.
# 迭代 6400 || Loss: 3.8124 || 10iter: 10.5031 sec.
# 迭代 6410 || Loss: 3.5485 || 10iter: 10.5680 sec.
# 迭代 6420 || Loss: 3.6339 || 10iter: 10.3668 sec.
# 迭代 6430 || Loss: 3.9013 || 10iter: 10.3691 sec.
# 迭代 6440 || Loss: 3.4187 || 10iter: 10.1738 sec.
# -------------
# epoch 36 || Epoch_TRAIN_Loss:668.5314 ||Epoch_VAL_Loss:0.0000
# timer:  191.3625 sec.
# -------------
# Epoch 37/50
# -------------
# （train）
# 迭代 6450 || Loss: 4.1408 || 10iter: 6.3483 sec.
# 迭代 6460 || Loss: 3.6741 || 10iter: 10.3776 sec.
# 迭代 6470 || Loss: 3.7319 || 10iter: 10.1440 sec.
# 迭代 6480 || Loss: 2.9300 || 10iter: 10.5319 sec.
# 迭代 6490 || Loss: 3.2966 || 10iter: 10.4661 sec.
# 迭代 6500 || Loss: 4.0446 || 10iter: 10.4597 sec.
# 迭代 6510 || Loss: 3.6861 || 10iter: 10.2226 sec.
# 迭代 6520 || Loss: 3.5871 || 10iter: 10.2661 sec.
# 迭代 6530 || Loss: 3.4833 || 10iter: 10.4006 sec.
# 迭代 6540 || Loss: 3.9025 || 10iter: 10.4081 sec.
# 迭代 6550 || Loss: 3.4931 || 10iter: 10.0661 sec.
# 迭代 6560 || Loss: 3.4997 || 10iter: 10.1803 sec.
# 迭代 6570 || Loss: 4.0251 || 10iter: 10.4317 sec.
# 迭代 6580 || Loss: 4.0613 || 10iter: 10.5495 sec.
# 迭代 6590 || Loss: 3.8170 || 10iter: 10.5008 sec.
# 迭代 6600 || Loss: 4.3457 || 10iter: 10.4153 sec.
# 迭代 6610 || Loss: 4.2158 || 10iter: 10.2769 sec.
# 迭代 6620 || Loss: 3.7231 || 10iter: 10.3547 sec.
# -------------
# epoch 37 || Epoch_TRAIN_Loss:661.8780 ||Epoch_VAL_Loss:0.0000
# timer:  191.6182 sec.
# -------------
# Epoch 38/50
# -------------
# （train）
# 迭代 6630 || Loss: 3.8478 || 10iter: 7.0909 sec.
# 迭代 6640 || Loss: 3.5664 || 10iter: 10.4850 sec.
# 迭代 6650 || Loss: 3.4957 || 10iter: 10.5168 sec.
# 迭代 6660 || Loss: 3.9494 || 10iter: 10.3739 sec.
# 迭代 6670 || Loss: 3.7024 || 10iter: 10.1216 sec.
# 迭代 6680 || Loss: 4.0242 || 10iter: 10.5534 sec.
# 迭代 6690 || Loss: 3.4060 || 10iter: 10.1944 sec.
# 迭代 6700 || Loss: 3.4839 || 10iter: 10.6015 sec.
# 迭代 6710 || Loss: 3.9441 || 10iter: 10.4103 sec.
# 迭代 6720 || Loss: 3.5923 || 10iter: 10.3510 sec.
# 迭代 6730 || Loss: 4.4653 || 10iter: 10.7482 sec.
# 迭代 6740 || Loss: 3.8409 || 10iter: 10.2102 sec.
# 迭代 6750 || Loss: 3.3944 || 10iter: 10.6481 sec.
# 迭代 6760 || Loss: 3.9643 || 10iter: 10.2958 sec.
# 迭代 6770 || Loss: 3.8738 || 10iter: 10.6281 sec.
# 迭代 6780 || Loss: 3.2921 || 10iter: 10.4785 sec.
# 迭代 6790 || Loss: 3.8463 || 10iter: 10.3981 sec.
# 迭代 6800 || Loss: 3.3559 || 10iter: 10.3860 sec.
# -------------
# epoch 38 || Epoch_TRAIN_Loss:656.2982 ||Epoch_VAL_Loss:0.0000
# timer:  192.5138 sec.
# -------------
# Epoch 39/50
# -------------
# （train）
# 迭代 6810 || Loss: 3.8613 || 10iter: 8.0987 sec.
# 迭代 6820 || Loss: 3.3350 || 10iter: 10.3338 sec.
# 迭代 6830 || Loss: 3.4045 || 10iter: 10.5733 sec.
# 迭代 6840 || Loss: 4.0210 || 10iter: 10.3665 sec.
# 迭代 6850 || Loss: 3.3630 || 10iter: 10.4292 sec.
# 迭代 6860 || Loss: 3.4957 || 10iter: 10.3476 sec.
# 迭代 6870 || Loss: 3.8855 || 10iter: 10.5315 sec.
# 迭代 6880 || Loss: 3.7243 || 10iter: 10.4752 sec.
# 迭代 6890 || Loss: 3.9420 || 10iter: 10.5932 sec.
# 迭代 6900 || Loss: 3.9153 || 10iter: 10.4532 sec.
# 迭代 6910 || Loss: 4.0744 || 10iter: 10.1780 sec.
# 迭代 6920 || Loss: 3.6192 || 10iter: 10.5362 sec.
# 迭代 6930 || Loss: 3.9342 || 10iter: 10.3792 sec.
# 迭代 6940 || Loss: 3.3548 || 10iter: 10.2630 sec.
# 迭代 6950 || Loss: 3.6874 || 10iter: 10.3202 sec.
# 迭代 6960 || Loss: 4.2182 || 10iter: 10.1385 sec.
# 迭代 6970 || Loss: 3.8583 || 10iter: 10.3040 sec.
# 迭代 6980 || Loss: 3.7462 || 10iter: 10.6379 sec.
# -------------
# epoch 39 || Epoch_TRAIN_Loss:658.0119 ||Epoch_VAL_Loss:0.0000
# timer:  191.9196 sec.
# -------------
# Epoch 40/50
# -------------
# （train）
# 迭代 6990 || Loss: 3.6348 || 10iter: 9.4513 sec.
# 迭代 7000 || Loss: 3.2049 || 10iter: 10.4551 sec.
# 迭代 7010 || Loss: 3.4911 || 10iter: 10.6403 sec.
# 迭代 7020 || Loss: 3.7807 || 10iter: 10.5516 sec.
# 迭代 7030 || Loss: 3.6521 || 10iter: 10.2506 sec.
# 迭代 7040 || Loss: 3.3625 || 10iter: 10.6067 sec.
# 迭代 7050 || Loss: 3.6570 || 10iter: 10.4899 sec.
# 迭代 7060 || Loss: 3.5312 || 10iter: 10.4751 sec.
# 迭代 7070 || Loss: 3.5481 || 10iter: 10.2733 sec.
# 迭代 7080 || Loss: 3.3670 || 10iter: 10.1889 sec.
# 迭代 7090 || Loss: 3.5917 || 10iter: 10.4465 sec.
# 迭代 7100 || Loss: 3.4313 || 10iter: 10.5064 sec.
# 迭代 7110 || Loss: 4.2520 || 10iter: 10.4143 sec.
# 迭代 7120 || Loss: 3.8980 || 10iter: 10.4698 sec.
# 迭代 7130 || Loss: 3.5201 || 10iter: 10.3946 sec.
# 迭代 7140 || Loss: 3.5532 || 10iter: 10.4531 sec.
# 迭代 7150 || Loss: 3.1922 || 10iter: 10.2186 sec.
# 迭代 7160 || Loss: 3.4889 || 10iter: 9.9570 sec.
# -------------
# （val）
# -------------
# epoch 40 || Epoch_TRAIN_Loss:646.9932 ||Epoch_VAL_Loss:708.2591
# timer:  271.6294 sec.
# -------------
# Epoch 41/50
# -------------
# （train）
# 迭代 7170 || Loss: 3.7866 || 10iter: 10.3667 sec.
# 迭代 7180 || Loss: 4.2814 || 10iter: 10.5262 sec.
# 迭代 7190 || Loss: 3.5515 || 10iter: 10.4827 sec.
# 迭代 7200 || Loss: 4.1823 || 10iter: 10.4157 sec.
# 迭代 7210 || Loss: 3.5094 || 10iter: 10.4089 sec.
# 迭代 7220 || Loss: 3.8575 || 10iter: 10.4823 sec.
# 迭代 7230 || Loss: 3.9502 || 10iter: 10.2535 sec.
# 迭代 7240 || Loss: 3.6341 || 10iter: 10.5112 sec.
# 迭代 7250 || Loss: 3.6759 || 10iter: 10.3023 sec.
# 迭代 7260 || Loss: 3.6854 || 10iter: 10.5824 sec.
# 迭代 7270 || Loss: 3.5850 || 10iter: 10.4011 sec.
# 迭代 7280 || Loss: 3.8685 || 10iter: 10.6028 sec.
# 迭代 7290 || Loss: 3.8263 || 10iter: 10.6535 sec.
# 迭代 7300 || Loss: 3.1909 || 10iter: 10.4506 sec.
# 迭代 7310 || Loss: 3.4876 || 10iter: 10.5394 sec.
# 迭代 7320 || Loss: 3.0230 || 10iter: 10.1886 sec.
# 迭代 7330 || Loss: 4.0116 || 10iter: 10.3444 sec.
# -------------
# epoch 41 || Epoch_TRAIN_Loss:645.6828 ||Epoch_VAL_Loss:0.0000
# timer:  192.5820 sec.
# -------------
# Epoch 42/50
# -------------
# （train）
# 迭代 7340 || Loss: 2.9118 || 10iter: 0.7847 sec.
# 迭代 7350 || Loss: 3.7106 || 10iter: 10.6462 sec.
# 迭代 7360 || Loss: 3.9027 || 10iter: 10.2843 sec.
# 迭代 7370 || Loss: 3.4931 || 10iter: 10.4118 sec.
# 迭代 7380 || Loss: 3.5154 || 10iter: 10.5442 sec.
# 迭代 7390 || Loss: 3.5657 || 10iter: 10.4082 sec.
# 迭代 7400 || Loss: 3.7507 || 10iter: 10.4035 sec.
# 迭代 7410 || Loss: 3.0410 || 10iter: 10.3314 sec.
# 迭代 7420 || Loss: 3.7291 || 10iter: 10.4734 sec.
# 迭代 7430 || Loss: 3.6516 || 10iter: 10.5010 sec.
# 迭代 7440 || Loss: 3.5822 || 10iter: 10.2901 sec.
# 迭代 7450 || Loss: 4.0306 || 10iter: 10.3228 sec.
# 迭代 7460 || Loss: 3.4819 || 10iter: 10.4293 sec.
# 迭代 7470 || Loss: 3.6929 || 10iter: 10.2172 sec.
# 迭代 7480 || Loss: 3.3706 || 10iter: 10.4910 sec.
# 迭代 7490 || Loss: 3.7922 || 10iter: 10.3176 sec.
# 迭代 7500 || Loss: 3.4547 || 10iter: 10.3481 sec.
# 迭代 7510 || Loss: 3.7599 || 10iter: 10.5153 sec.
# -------------
# epoch 42 || Epoch_TRAIN_Loss:634.6900 ||Epoch_VAL_Loss:0.0000
# timer:  191.9161 sec.
# -------------
# Epoch 43/50
# -------------
# （train）
# 迭代 7520 || Loss: 3.5498 || 10iter: 1.7654 sec.
# 迭代 7530 || Loss: 2.5326 || 10iter: 10.1804 sec.
# 迭代 7540 || Loss: 3.2354 || 10iter: 10.4797 sec.
# 迭代 7550 || Loss: 3.6353 || 10iter: 10.6846 sec.
# 迭代 7560 || Loss: 3.4590 || 10iter: 10.7194 sec.
# 迭代 7570 || Loss: 4.1016 || 10iter: 10.4987 sec.
# 迭代 7580 || Loss: 3.6150 || 10iter: 10.3318 sec.
# 迭代 7590 || Loss: 3.4654 || 10iter: 10.6482 sec.
# 迭代 7600 || Loss: 3.5303 || 10iter: 10.4420 sec.
# 迭代 7610 || Loss: 3.1530 || 10iter: 9.9870 sec.
# 迭代 7620 || Loss: 3.6787 || 10iter: 10.5107 sec.
# 迭代 7630 || Loss: 4.0475 || 10iter: 10.6552 sec.
# 迭代 7640 || Loss: 3.7981 || 10iter: 10.3133 sec.
# 迭代 7650 || Loss: 3.6269 || 10iter: 10.4076 sec.
# 迭代 7660 || Loss: 3.7355 || 10iter: 10.2177 sec.
# 迭代 7670 || Loss: 3.7122 || 10iter: 10.4332 sec.
# 迭代 7680 || Loss: 3.3989 || 10iter: 10.3243 sec.
# 迭代 7690 || Loss: 3.4462 || 10iter: 10.4902 sec.
# -------------
# epoch 43 || Epoch_TRAIN_Loss:637.3012 ||Epoch_VAL_Loss:0.0000
# timer:  192.4713 sec.
# -------------
# Epoch 44/50
# -------------
# （train）
# 迭代 7700 || Loss: 4.5187 || 10iter: 2.8810 sec.
# 迭代 7710 || Loss: 3.7590 || 10iter: 10.4779 sec.
# 迭代 7720 || Loss: 3.1262 || 10iter: 10.3947 sec.
# 迭代 7730 || Loss: 3.2667 || 10iter: 10.3150 sec.
# 迭代 7740 || Loss: 3.5724 || 10iter: 10.4429 sec.
# 迭代 7750 || Loss: 3.5358 || 10iter: 10.3281 sec.
# 迭代 7760 || Loss: 3.4743 || 10iter: 10.2171 sec.
# 迭代 7770 || Loss: 3.8414 || 10iter: 10.5156 sec.
# 迭代 7780 || Loss: 3.1547 || 10iter: 10.3578 sec.
# 迭代 7790 || Loss: 2.9826 || 10iter: 10.5144 sec.
# 迭代 7800 || Loss: 3.6452 || 10iter: 10.4023 sec.
# 迭代 7810 || Loss: 3.2639 || 10iter: 10.2899 sec.
# 迭代 7820 || Loss: 3.4805 || 10iter: 10.7961 sec.
# 迭代 7830 || Loss: 3.8029 || 10iter: 10.3289 sec.
# 迭代 7840 || Loss: 3.9409 || 10iter: 10.5089 sec.
# 迭代 7850 || Loss: 3.6830 || 10iter: 10.6574 sec.
# 迭代 7860 || Loss: 3.0727 || 10iter: 10.4519 sec.
# 迭代 7870 || Loss: 4.1033 || 10iter: 10.6133 sec.
# -------------
# epoch 44 || Epoch_TRAIN_Loss:628.7945 ||Epoch_VAL_Loss:0.0000
# timer:  192.8685 sec.
# -------------
# Epoch 45/50
# -------------
# （train）
# 迭代 7880 || Loss: 3.1758 || 10iter: 4.0167 sec.
# 迭代 7890 || Loss: 3.5759 || 10iter: 10.4753 sec.
# 迭代 7900 || Loss: 3.7283 || 10iter: 10.2609 sec.
# 迭代 7910 || Loss: 3.7423 || 10iter: 9.9343 sec.
# 迭代 7920 || Loss: 4.0077 || 10iter: 10.1876 sec.
# 迭代 7930 || Loss: 3.9467 || 10iter: 10.1802 sec.
# 迭代 7940 || Loss: 3.4790 || 10iter: 10.5853 sec.
# 迭代 7950 || Loss: 3.3289 || 10iter: 10.2042 sec.
# 迭代 7960 || Loss: 3.1343 || 10iter: 10.4487 sec.
# 迭代 7970 || Loss: 3.5748 || 10iter: 10.3321 sec.
# 迭代 7980 || Loss: 3.4453 || 10iter: 10.3917 sec.
# 迭代 7990 || Loss: 3.0696 || 10iter: 10.2189 sec.
# 迭代 8000 || Loss: 3.7679 || 10iter: 10.2817 sec.
# 迭代 8010 || Loss: 2.8892 || 10iter: 10.4531 sec.
# 迭代 8020 || Loss: 3.2487 || 10iter: 10.3758 sec.
# 迭代 8030 || Loss: 3.5192 || 10iter: 10.5064 sec.
# 迭代 8040 || Loss: 3.6212 || 10iter: 10.3294 sec.
# 迭代 8050 || Loss: 3.7921 || 10iter: 10.6145 sec.
# -------------
# epoch 45 || Epoch_TRAIN_Loss:628.7019 ||Epoch_VAL_Loss:0.0000
# timer:  190.8021 sec.
# -------------
# Epoch 46/50
# -------------
# （train）
# 迭代 8060 || Loss: 3.6888 || 10iter: 4.9986 sec.
# 迭代 8070 || Loss: 3.1107 || 10iter: 10.4184 sec.
# 迭代 8080 || Loss: 3.6423 || 10iter: 10.5448 sec.
# 迭代 8090 || Loss: 3.4738 || 10iter: 10.1706 sec.
# 迭代 8100 || Loss: 4.0693 || 10iter: 10.3222 sec.
# 迭代 8110 || Loss: 3.7171 || 10iter: 10.4729 sec.
# 迭代 8120 || Loss: 3.3503 || 10iter: 10.8572 sec.
# 迭代 8130 || Loss: 3.4292 || 10iter: 10.6859 sec.
# 迭代 8140 || Loss: 3.4259 || 10iter: 10.4566 sec.
# 迭代 8150 || Loss: 3.6479 || 10iter: 10.5051 sec.
# 迭代 8160 || Loss: 3.2801 || 10iter: 10.3960 sec.
# 迭代 8170 || Loss: 3.2516 || 10iter: 10.6876 sec.
# 迭代 8180 || Loss: 3.6552 || 10iter: 10.5625 sec.
# 迭代 8190 || Loss: 3.4688 || 10iter: 10.7339 sec.
# 迭代 8200 || Loss: 3.3486 || 10iter: 10.6141 sec.
# 迭代 8210 || Loss: 3.5080 || 10iter: 10.7931 sec.
# 迭代 8220 || Loss: 3.6697 || 10iter: 10.5277 sec.
# 迭代 8230 || Loss: 3.4073 || 10iter: 10.8238 sec.
# -------------
# epoch 46 || Epoch_TRAIN_Loss:624.6431 ||Epoch_VAL_Loss:0.0000
# timer:  194.7965 sec.
# -------------
# Epoch 47/50
# -------------
# （train）
# 迭代 8240 || Loss: 3.3077 || 10iter: 5.9026 sec.
# 迭代 8250 || Loss: 3.4656 || 10iter: 10.5474 sec.
# 迭代 8260 || Loss: 3.0229 || 10iter: 10.4285 sec.
# 迭代 8270 || Loss: 3.3209 || 10iter: 10.9275 sec.
# 迭代 8280 || Loss: 3.2111 || 10iter: 10.7024 sec.
# 迭代 8290 || Loss: 3.5787 || 10iter: 10.3958 sec.
# 迭代 8300 || Loss: 3.2266 || 10iter: 10.5897 sec.
# 迭代 8310 || Loss: 3.5275 || 10iter: 10.6161 sec.
# 迭代 8320 || Loss: 3.4817 || 10iter: 10.8431 sec.
# 迭代 8330 || Loss: 3.4167 || 10iter: 10.3747 sec.
# 迭代 8340 || Loss: 3.5492 || 10iter: 10.4824 sec.
# 迭代 8350 || Loss: 3.3100 || 10iter: 10.7705 sec.
# 迭代 8360 || Loss: 3.3483 || 10iter: 10.5116 sec.
# 迭代 8370 || Loss: 3.4198 || 10iter: 10.5517 sec.
# 迭代 8380 || Loss: 3.9172 || 10iter: 10.6946 sec.
# 迭代 8390 || Loss: 3.1847 || 10iter: 10.4106 sec.
# 迭代 8400 || Loss: 3.2655 || 10iter: 10.7388 sec.
# 迭代 8410 || Loss: 3.8280 || 10iter: 10.5625 sec.
# -------------
# epoch 47 || Epoch_TRAIN_Loss:615.4873 ||Epoch_VAL_Loss:0.0000
# timer:  195.0740 sec.
# -------------
# Epoch 48/50
# -------------
# （train）
# 迭代 8420 || Loss: 3.6449 || 10iter: 7.2951 sec.
# 迭代 8430 || Loss: 3.8671 || 10iter: 10.3354 sec.
# 迭代 8440 || Loss: 3.6946 || 10iter: 10.2974 sec.
# 迭代 8450 || Loss: 3.5706 || 10iter: 10.4985 sec.
# 迭代 8460 || Loss: 3.3785 || 10iter: 10.3872 sec.
# 迭代 8470 || Loss: 3.2275 || 10iter: 10.2736 sec.
# 迭代 8480 || Loss: 3.0274 || 10iter: 10.5443 sec.
# 迭代 8490 || Loss: 3.1515 || 10iter: 10.4580 sec.
# 迭代 8500 || Loss: 3.5040 || 10iter: 10.2655 sec.
# 迭代 8510 || Loss: 3.9644 || 10iter: 10.3449 sec.
# 迭代 8520 || Loss: 3.4604 || 10iter: 10.3489 sec.
# 迭代 8530 || Loss: 3.3445 || 10iter: 10.4165 sec.
# 迭代 8540 || Loss: 3.5604 || 10iter: 10.1802 sec.
# 迭代 8550 || Loss: 3.4066 || 10iter: 10.3914 sec.
# 迭代 8560 || Loss: 3.6221 || 10iter: 10.5903 sec.
# 迭代 8570 || Loss: 4.2151 || 10iter: 10.4205 sec.
# 迭代 8580 || Loss: 3.5691 || 10iter: 10.2191 sec.
# 迭代 8590 || Loss: 3.8322 || 10iter: 10.6924 sec.
# -------------
# epoch 48 || Epoch_TRAIN_Loss:616.6893 ||Epoch_VAL_Loss:0.0000
# timer:  191.8847 sec.
# -------------
# Epoch 49/50
# -------------
# （train）
# 迭代 8600 || Loss: 3.6490 || 10iter: 8.3451 sec.
# 迭代 8610 || Loss: 3.2761 || 10iter: 10.4036 sec.
# 迭代 8620 || Loss: 3.3662 || 10iter: 10.2052 sec.
# 迭代 8630 || Loss: 3.3261 || 10iter: 10.2840 sec.
# 迭代 8640 || Loss: 3.4230 || 10iter: 10.2695 sec.
# 迭代 8650 || Loss: 3.5855 || 10iter: 10.4437 sec.
# 迭代 8660 || Loss: 3.9620 || 10iter: 10.3231 sec.
# 迭代 8670 || Loss: 3.2997 || 10iter: 10.3796 sec.
# 迭代 8680 || Loss: 3.4492 || 10iter: 10.2032 sec.
# 迭代 8690 || Loss: 3.8911 || 10iter: 10.3999 sec.
# 迭代 8700 || Loss: 3.4728 || 10iter: 10.7821 sec.
# 迭代 8710 || Loss: 3.3287 || 10iter: 10.3609 sec.
# 迭代 8720 || Loss: 3.8517 || 10iter: 10.5815 sec.
# 迭代 8730 || Loss: 3.2122 || 10iter: 10.3088 sec.
# 迭代 8740 || Loss: 4.0267 || 10iter: 10.3043 sec.
# 迭代 8750 || Loss: 3.0704 || 10iter: 10.1968 sec.
# 迭代 8760 || Loss: 3.3362 || 10iter: 10.3555 sec.
# 迭代 8770 || Loss: 3.1441 || 10iter: 10.2771 sec.
# -------------
# epoch 49 || Epoch_TRAIN_Loss:610.4620 ||Epoch_VAL_Loss:0.0000
# timer:  191.3936 sec.
# -------------
# Epoch 50/50
# -------------
# （train）
# 迭代 8780 || Loss: 2.9782 || 10iter: 9.3802 sec.
# 迭代 8790 || Loss: 3.2503 || 10iter: 10.3321 sec.
# 迭代 8800 || Loss: 3.5477 || 10iter: 10.4173 sec.
# 迭代 8810 || Loss: 3.7515 || 10iter: 10.4826 sec.
# 迭代 8820 || Loss: 3.3812 || 10iter: 10.5157 sec.
# 迭代 8830 || Loss: 3.6147 || 10iter: 10.1211 sec.
# 迭代 8840 || Loss: 3.3912 || 10iter: 10.2974 sec.
# 迭代 8850 || Loss: 3.1168 || 10iter: 10.2720 sec.
# 迭代 8860 || Loss: 3.9228 || 10iter: 10.4774 sec.
# 迭代 8870 || Loss: 3.8100 || 10iter: 10.4094 sec.
# 迭代 8880 || Loss: 3.7404 || 10iter: 10.3119 sec.
# 迭代 8890 || Loss: 3.3581 || 10iter: 10.3914 sec.
# 迭代 8900 || Loss: 3.3453 || 10iter: 10.2414 sec.
# 迭代 8910 || Loss: 3.8019 || 10iter: 10.2288 sec.
# 迭代 8920 || Loss: 3.3596 || 10iter: 10.2899 sec.
# 迭代 8930 || Loss: 3.0973 || 10iter: 10.2294 sec.
# 迭代 8940 || Loss: 3.5725 || 10iter: 10.2877 sec.
# 迭代 8950 || Loss: 3.6211 || 10iter: 10.1599 sec.
# -------------
# （val）
# -------------
# epoch 50 || Epoch_TRAIN_Loss:605.4489 ||Epoch_VAL_Loss:688.3017
# timer:  269.9358 sec.
# -------------
# Epoch 51/50
# -------------
# （train）
# 迭代 8960 || Loss: 3.2108 || 10iter: 10.3274 sec.
# 迭代 8970 || Loss: 3.6413 || 10iter: 10.6570 sec.
# 迭代 8980 || Loss: 3.6519 || 10iter: 10.7103 sec.
# 迭代 8990 || Loss: 3.0330 || 10iter: 10.7903 sec.
# 迭代 9000 || Loss: 4.2644 || 10iter: 10.7396 sec.
# 迭代 9010 || Loss: 3.7172 || 10iter: 10.6335 sec.
# 迭代 9020 || Loss: 3.1100 || 10iter: 10.3946 sec.
# 迭代 9030 || Loss: 3.8871 || 10iter: 10.6806 sec.
# 迭代 9040 || Loss: 3.0343 || 10iter: 10.3450 sec.
# 迭代 9050 || Loss: 2.8595 || 10iter: 10.5836 sec.
# 迭代 9060 || Loss: 2.8004 || 10iter: 10.5309 sec.
# 迭代 9070 || Loss: 3.0782 || 10iter: 10.5673 sec.
# 迭代 9080 || Loss: 3.9311 || 10iter: 10.4529 sec.
# 迭代 9090 || Loss: 3.7336 || 10iter: 10.1382 sec.
# 迭代 9100 || Loss: 4.1760 || 10iter: 10.1021 sec.
# 迭代 9110 || Loss: 2.9156 || 10iter: 10.5288 sec.
# 迭代 9120 || Loss: 3.7806 || 10iter: 10.3687 sec.
# -------------
# epoch 51 || Epoch_TRAIN_Loss:606.8269 ||Epoch_VAL_Loss:0.0000
# timer:  193.9368 sec.
